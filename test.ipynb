# %%
datasets = ['ETTh1', 'ETTh2', 'ETTm1', 'ETTm2', 'Traffic', 'Electricity']
mse_actual = [0.3757, 0.2914, 0.3209, 0.1778, 0.4464, 0.1737]
mse_baseline = [0.5753, 0.4995, 0.4227, 0.2632, 1.1090, 0.4995]
mse_diff = [mse_baseline[d] - mse_actual[d] for d in range(len(datasets))]
k_dataset = [5.5686, 6.4254, 10.8808, 6.5909, 13.8148, 5.4735]
k_model = [1.8414, 2.6278, 3.5806, 7.148, 2.3604, 1.9079]
ratios = [k_dataset[d] - k_model[d] for d in range(len(datasets))]
# Out:
# (11392, 96, 7)
